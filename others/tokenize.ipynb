# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("/mnt/cpfs2/models/qwen3/Qwen3-4B")

tokenizer(
    text="你好",
    return_tensors="pt",
    padding=True,
    truncation=True,
    max_length=100,
)
# Out:
# {'input_ids': tensor([[108386]]), 'attention_mask': tensor([[1]])}
