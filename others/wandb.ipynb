# %%
# import wandb
# from wandb.sdk.wandb_run import Run, Settings
# run = Run(
#     settings=Settings()
# )
# with open("/mnt/cpfs2/rzhang/tools/dev_patch/project_c_grpo/wandb/offline-run-20250926_173145-djxkajas/run-djxkajas.wandb", "rb") as f:
#     data = run._filesystem.open(f.name)
#     # data 是 zip 流，可以遍历里面的 JSON(L) 文件
